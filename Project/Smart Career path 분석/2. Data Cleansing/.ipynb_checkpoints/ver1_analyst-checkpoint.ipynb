# %%
import numpy as np
import pandas as pd
import string
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import re
import nltk
nltk.download('stopwords')
stopword = nltk.corpus.stopwords.words('english')
wn = nltk.WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_json('./applicantprofile_analyst.json',lines=True)
df_add = pd.read_json('./applicant.json',lines=True)
df = df.append(df_add)
df.head()
# Out:
#        Date Captured                                          Education  \
# 0  NaN    2019-11-09  [{'School': 'University of California, Irvine ...
# 1  NaN    2019-11-09  [{'School': 'University of Surrey', 'Degree': ...
# 2  NaN    2019-11-09  [{'School': 'University of California, Los Ang...
# 3  NaN    2019-11-09  [{'School': 'University of California, Berkele...
# 4  NaN    2019-11-09  [{'School': 'University of Pittsburgh College ...
#
#                                           Experience  \
# 0  [{'Job Title': 'Data Analyst', 'Company': 'NEX...
# 1  [{'Job Title': 'Analyst', 'Company': 'GLG (Ger...
# 2  [{'Job Title': 'Company Name Google', 'Company...
# 3  [{'Job Title': 'Strategy Analyst', 'Company': ...
# 4  [{'Job Title': 'Company Name Responsival', 'Co...
#
#                                   Industry Knowledge  \
# 0  [{'Skills': 'SEO'}, {'Skills': 'Business Devel...
# 1       [{'Skills': 'customer relation management'}]
# 2  [{'Skills': 'Project Management'}, {'Skills': ...
# 3  [{'Skills': 'Data Analysis'}, {'Skills': 'Even...
# 4  [{'Skills': 'Digital Marketing'}, {'Skills': '...
#
#                                 Interpersonal Skills  \
# 0  [{'Skills': 'Management'}, {'Skills': 'Custome...
# 1  [{'Skills': 'Problem Solving'}, {'Skills': 'ta...
# 2                                                NaN
# 3  [{'Skills': 'Leadership'}, {'Skills': 'Custome...
# 4  [{'Skills': 'Leadership'}, {'Skills': 'Communi...
#
#                          Job Title                Languages  \
# 0                     Data Analyst                      NaN
# 1  Analyst at Gerson Lehrman Group                      NaN
# 2         Regional Analyst, Google                      NaN
# 3    Strategy Analyst at Accenture                      NaN
# 4        Data Analyst at Microsoft  [{'Skills': 'Chinese'}]
#
#                      Location  \
# 0      Emeryville, California
# 1               United States
# 2  Greater New York City Area
# 3        Berkeley, California
# 4     Greater Pittsburgh Area
#
#                                         Other Skills  \
# 0  [{'Skills': 'Inbound Marketing'}, {'Skills': '...
# 1  [{'Skills': '由ъ꽌移�'}, {'Skills': '�봽濡쒖젥�듃 愿�由�...
# 2  [{'Skills': 'Marketing Research'}, {'Skills': ...
# 3                                                NaN
# 4                          [{'Skills': 'HootSuite'}]
#
#                                      Profile Summary             ProfileID  \
# 0  Detail-oriented marketing data analyst with st...         emmabobaekong
# 1                                                     jinwoo-kang-097b0977
# 2                                                        suzannesoojungbae
# 3                                                                hayliekim
# 4  A passionate and eager individual who is alway...         angeline-peng
#
#                                Skills & Endorsements  \
# 0  [{'Skills': 'Data Analysis'}, {'Skills': 'SQL'...
# 1  [{'Skills': 'market research'}, {'Skills': 'an...
# 2  [{'Skills': 'Online Advertising'}, {'Skills': ...
# 3  [{'Skills': 'Microsoft Office'}, {'Skills': 'P...
# 4  [{'Skills': 'Project Management'}, {'Skills': ...
#
#                                 Tools & Technologies  \
# 0  [{'Skills': 'Google Analytics'}, {'Skills': 'P...
# 1                                                NaN
# 2                                                NaN
# 3  [{'Skills': 'Microsoft Excel'}, {'Skills': 'Mi...
# 4  [{'Skills': 'Microsoft Office'}, {'Skills': 'Y...
#
#                                     _id
# 0  {'$oid': '5dc67f352d165786280a5e89'}
# 1  {'$oid': '5dc67f512d165786280a5e8b'}
# 2  {'$oid': '5dc67f692d165786280a5e8d'}
# 3  {'$oid': '5dc67f832d165786280a5e8f'}
# 4  {'$oid': '5dc67f9e2d165786280a5e91'}

# %%
## 복잡한 형태의 column을 일정한 형태로 맞춰주기위함
def prep_edu(ro):
    if ro ==[]:
        ro = [{'School':'No School','Degree':'No Degree','Date Attend':'No attend'}]
    else:
        ro=ro
    return ro

def prep_exp(ro):
    if ro==[]:
        ro = [{'Job Title':'','Company':'','Period':'','Years':'','Location':'','Description':''}]
    else:
        ro = ro
    return ro

def prep_sk(ro):
    if ro==[]:
        ro=[{'Skills':''}]
    else:
        ro=ro
    return ro

# %%
## 바로 apply를 하면 nan은 float type이라서 len가 안먹힌다.
## 각 column을 공통 type으로 맞춰주기 위해 nan값을 찾아 빈리스트로 대체
def nan_to_list(num):
    if num!=num:
        return list()
    else:
        return num

for i in df:
    df[i] = df[i].apply(lambda x: nan_to_list(x))

# %%
df['Skills & Endorsements'] = df['Skills & Endorsements'].apply(lambda x:prep_sk(x))
df['Tools & Technologies'] = df['Tools & Technologies'].apply(lambda x:prep_sk(x))
df['Interpersonal Skills']=df['Interpersonal Skills'].apply(lambda x:prep_sk(x))
df['Other Skills'] = df['Other Skills'].apply(lambda x:prep_sk(x))
df['Industry Knowledge'] = df['Industry Knowledge'].apply(lambda x:prep_sk(x))
df['Experience'] = df['Experience'].apply(lambda x:prep_exp(x))
df['Education'] = df['Education'].apply(lambda x:prep_edu(x))

# %%
## nlp에 필요한 function정의
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct
def tokenize(text):
    tokens = re.split('\W+', text)
    return tokens
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopword]
    return text
def lemmatizing(tokenized_text):
    text = [wn.lemmatize(word) for word in tokenized_text]
    return text

# %%
## skill들을 빼올수 있는 함수 생성
def get_skill(sel):
    skill_list = []
    for i in range(len(sel)):
        skill_list.append(sel[i]['Skills'])
    return skill_list

# %%
## 각 skill column에서 모든 skill들 list를 구하는 함수
def get_skill_list(ser):
    ret = []
    for idx in range(len(ser)):
        for i,v in enumerate(ser.iloc[idx]):
            ret.append(v)
    return ret

# %%
for col in ['Skills & Endorsements','Tools & Technologies','Interpersonal Skills','Other Skills','Industry Knowledge']:
    df[col] = df[col].apply(lambda x:get_skill(x))

df.head()
# Out:
#       Date Captured                                          Education  \
# 0  []    2019-11-09  [{'School': 'University of California, Irvine ...
# 1  []    2019-11-09  [{'School': 'University of Surrey', 'Degree': ...
# 2  []    2019-11-09  [{'School': 'University of California, Los Ang...
# 3  []    2019-11-09  [{'School': 'University of California, Berkele...
# 4  []    2019-11-09  [{'School': 'University of Pittsburgh College ...
#
#                                           Experience  \
# 0  [{'Job Title': 'Data Analyst', 'Company': 'NEX...
# 1  [{'Job Title': 'Analyst', 'Company': 'GLG (Ger...
# 2  [{'Job Title': 'Company Name Google', 'Company...
# 3  [{'Job Title': 'Strategy Analyst', 'Company': ...
# 4  [{'Job Title': 'Company Name Responsival', 'Co...
#
#                                   Industry Knowledge  \
# 0  [SEO, Business Development, Online Marketing, ...
# 1                     [customer relation management]
# 2         [Project Management, Competitive Analysis]
# 3      [Data Analysis, Event Planning, Social Media]
# 4  [Digital Marketing, Public Relations, Social M...
#
#                            Interpersonal Skills  \
# 0                [Management, Customer Service]
# 1          [Problem Solving, talent management]
# 2                                            []
# 3    [Leadership, Customer Service, Management]
# 4  [Leadership, Communication, Public Speaking]
#
#                          Job Title                Languages  \
# 0                     Data Analyst                       []
# 1  Analyst at Gerson Lehrman Group                       []
# 2         Regional Analyst, Google                       []
# 3    Strategy Analyst at Accenture                       []
# 4        Data Analyst at Microsoft  [{'Skills': 'Chinese'}]
#
#                      Location  \
# 0      Emeryville, California
# 1               United States
# 2  Greater New York City Area
# 3        Berkeley, California
# 4     Greater Pittsburgh Area
#
#                                         Other Skills  \
# 0  [Inbound Marketing, DoubleClick, Ad Networks, ...
# 1  [由ъ꽌移�, �봽濡쒖젥�듃 愿�由�, MS �삤�뵾�뒪, 怨좉컼�꽌鍮꾩뒪, ���...
# 2  [Marketing Research, Strategic Insights, Consu...
# 3                                                 []
# 4                                        [HootSuite]
#
#                                      Profile Summary             ProfileID  \
# 0  Detail-oriented marketing data analyst with st...         emmabobaekong
# 1                                                     jinwoo-kang-097b0977
# 2                                                        suzannesoojungbae
# 3                                                                hayliekim
# 4  A passionate and eager individual who is alway...         angeline-peng
#
#                                Skills & Endorsements  \
# 0                      [Data Analysis, SQL, Tableau]
# 1           [market research, analyzing, recruiting]
# 2  [Online Advertising, Digital Marketing, Digita...
# 3      [Microsoft Office, Public Speaking, Research]
# 4  [Project Management, Strategic Planning, Socia...
#
#                                 Tools & Technologies  \
# 0  [Google Analytics, Python, Google Adwords, Goo...
# 1                                                 []
# 2                                                 []
# 3  [Microsoft Excel, Microsoft Word, Microsoft Po...
# 4            [Microsoft Office, YouTube, Java, HTML]
#
#                                     _id
# 0  {'$oid': '5dc67f352d165786280a5e89'}
# 1  {'$oid': '5dc67f512d165786280a5e8b'}
# 2  {'$oid': '5dc67f692d165786280a5e8d'}
# 3  {'$oid': '5dc67f832d165786280a5e8f'}
# 4  {'$oid': '5dc67f9e2d165786280a5e91'}

# %%
skill_list1 = get_skill_list(df['Skills & Endorsements'])
skill_list2 = get_skill_list(df['Tools & Technologies'])
skill_list3 = get_skill_list(df['Interpersonal Skills'])
skill_list4 = get_skill_list(df['Other Skills'])
skill_list5 = get_skill_list(df['Industry Knowledge'])

# %%
## skill별 Top 10
print(pd.Series(skill_list1).value_counts().iloc[:10])
print('\n',pd.Series(skill_list2).value_counts().iloc[:10])
print('\n',pd.Series(skill_list3).value_counts().iloc[:10])
print('\n',pd.Series(skill_list4).value_counts().iloc[:10])
print('\n',pd.Series(skill_list5).value_counts().iloc[:10])
## Issue Analyst의 경우 skills:'','',이런식으로 되어있는 경우가 있음
# Out:
#                     1606
# Microsoft Office     280
# Microsoft Excel      251
# Leadership           191
# Data Analysis        145
# Public Speaking      125
# Customer Service     107
# Marketing             89
# Social Media          84
# SQL                   83
# dtype: int64
#
#                          869
# Microsoft Excel         528
# Microsoft Office        472
# Microsoft Word          450
# PowerPoint              377
# Microsoft PowerPoint    317
# SQL                     192
# Tableau                 163
# R                       139
# Python                  138
# dtype: int64
#
#                      963
# Leadership          416
# Public Speaking     365
# Management          343
# Customer Service    343
# Teamwork            334
# Time Management     200
# Communication       119
# Team Leadership     103
# Fundraising          74
# dtype: int64
#
#                         1039
# Social Networking       159
# Hospitality              39
# Networking               35
# Data Analytics           34
# Hotels                   26
# Marketing Research       25
# Marketing Analytics      21
# Korean                   21
# Process Improvement      20
# dtype: int64
#
#                            814
# Research                  385
# Social Media              385
# Data Analysis             349
# Marketing                 282
# Event Planning            264
# Project Management        242
# Marketing Strategy        175
# Social Media Marketing    174
# Sales                     163
# dtype: int64

# %%
## 가지고 있는 스킬의 수를 구하는 함수
def get_cnt_skill(ro):
    return len(ro)

# %%
df['endorsement cnt'] = df['Skills & Endorsements'].apply(lambda x:get_cnt_skill(x))
df['tool cnt']        = df['Tools & Technologies'].apply(lambda x:get_cnt_skill(x))
df['personal cnt']    = df['Interpersonal Skills'].apply(lambda x:get_cnt_skill(x))
df['etc cnt']         = df['Other Skills'].apply(lambda x:get_cnt_skill(x))
df['knowledge cnt']   = df['Industry Knowledge'].apply(lambda x:get_cnt_skill(x))

# %%
## skill명과 skill column을 받아 스킬수를 출력해보자
def have_skill(ski,ser):
    tf=0
    for idx in range(len(ser)):
        if ski in ser.iloc[idx]:
            tf+=1
    return tf

# %%
ski = input('조회할 스킬')
col = input('조회할 컬럼명')
print('{}를 갖고 있는 사람의 수는 {}'.format(ski,have_skill(ski,df[col])))
# Out:
# 조회할 스킬Python
# 조회할 컬럼명Tools & Technologies
# Python를 갖고 있는 사람의 수는 138

# %%
## 스킬 컬럼을 선택했을때 갖고 있는 스킬의 분포를 확인하고 싶다.
def get_dist(col,tp_sel):
    plt.figure(figsize = (10,5))
    a=list()
    for idx in range(len(df[col])):
        for i,v in enumerate(df[col].iloc[idx]):
            a.append(v)
    return pd.Series(a).value_counts().iloc[:tp_sel].plot(kind='bar')
    #return df_skill[col].value_counts()

# %%
col=input('조회할 컬럼')
tp_sel = int(input('Top몇'))
get_dist(col,tp_sel)
# Out:
# 조회할 컬럼Tools & Technologies
# Top몇3

# %%
def get_year(tr):
    mo_tr = 0
    ye_tr = 0
    year = 0
    for i in range(len(tr)):
        
        tr[i]['Years'] = tr[i]['Years'].replace(' ','').replace('yrs','yr').replace('mos','mo')
        if 'yr' in tr[i]['Years'] and 'mo' in tr[i]['Years']:
            ye_tr+=np.int(tr[i]['Years'].replace('mo','').split('yr')[0])
            mo_tr+=np.int(tr[i]['Years'].replace('mo','').split('yr')[1])
        elif 'yr' not in tr[i]['Years'] and 'mo' in tr[i]['Years']:
            mo_tr+=np.int(tr[i]['Years'].replace('mo',''))
            ye_tr+=0
        elif 'yr' in tr[i]['Years'] and 'mo' not in tr[i]['Years']:
            ye_tr+=np.int(tr[i]['Years'].replace('yr',''))
            mo_tr+=0
        else:
            ye_tr+=0
            mo_tr+= 0
    year = int(round(((ye_tr*12)+mo_tr)/12,0))
    return year

# %%
df['Years'] = df['Experience'].apply(lambda x:get_year(x))

# %%
def get_school(ser):
     
    if len(ser)==0:
        school = 'No School'
    else:
        school = ser[0]['School']
    return school

# %%
df['School'] = df['Education'].apply(lambda x:get_school(x))
df.head()
# Out:
#       Date Captured                                          Education  \
# 0  []    2019-11-09  [{'School': 'University of California, Irvine ...
# 1  []    2019-11-09  [{'School': 'University of Surrey', 'Degree': ...
# 2  []    2019-11-09  [{'School': 'University of California, Los Ang...
# 3  []    2019-11-09  [{'School': 'University of California, Berkele...
# 4  []    2019-11-09  [{'School': 'University of Pittsburgh College ...
#
#                                           Experience  \
# 0  [{'Job Title': 'Data Analyst', 'Company': 'NEX...
# 1  [{'Job Title': 'Analyst', 'Company': 'GLG (Ger...
# 2  [{'Job Title': 'Company Name Google', 'Company...
# 3  [{'Job Title': 'Strategy Analyst', 'Company': ...
# 4  [{'Job Title': 'Company Name Responsival', 'Co...
#
#                                   Industry Knowledge  \
# 0  [SEO, Business Development, Online Marketing, ...
# 1                     [customer relation management]
# 2         [Project Management, Competitive Analysis]
# 3      [Data Analysis, Event Planning, Social Media]
# 4  [Digital Marketing, Public Relations, Social M...
#
#                            Interpersonal Skills  \
# 0                [Management, Customer Service]
# 1          [Problem Solving, talent management]
# 2                                            []
# 3    [Leadership, Customer Service, Management]
# 4  [Leadership, Communication, Public Speaking]
#
#                          Job Title                Languages  \
# 0                     Data Analyst                       []
# 1  Analyst at Gerson Lehrman Group                       []
# 2         Regional Analyst, Google                       []
# 3    Strategy Analyst at Accenture                       []
# 4        Data Analyst at Microsoft  [{'Skills': 'Chinese'}]
#
#                      Location  \
# 0      Emeryville, California
# 1               United States
# 2  Greater New York City Area
# 3        Berkeley, California
# 4     Greater Pittsburgh Area
#
#                                         Other Skills  ...  \
# 0  [Inbound Marketing, DoubleClick, Ad Networks, ...  ...
# 1  [由ъ꽌移�, �봽濡쒖젥�듃 愿�由�, MS �삤�뵾�뒪, 怨좉컼�꽌鍮꾩뒪, ���...  ...
# 2  [Marketing Research, Strategic Insights, Consu...  ...
# 3                                                 []  ...
# 4                                        [HootSuite]  ...
#
#                                Skills & Endorsements  \
# 0                      [Data Analysis, SQL, Tableau]
# 1           [market research, analyzing, recruiting]
# 2  [Online Advertising, Digital Marketing, Digita...
# 3      [Microsoft Office, Public Speaking, Research]
# 4  [Project Management, Strategic Planning, Socia...
#
#                                 Tools & Technologies  \
# 0  [Google Analytics, Python, Google Adwords, Goo...
# 1                                                 []
# 2                                                 []
# 3  [Microsoft Excel, Microsoft Word, Microsoft Po...
# 4            [Microsoft Office, YouTube, Java, HTML]
#
#                                     _id endorsement cnt tool cnt  \
# 0  {'$oid': '5dc67f352d165786280a5e89'}               3       14
# 1  {'$oid': '5dc67f512d165786280a5e8b'}               3        1
# 2  {'$oid': '5dc67f692d165786280a5e8d'}               3        1
# 3  {'$oid': '5dc67f832d165786280a5e8f'}               3        5
# 4  {'$oid': '5dc67f9e2d165786280a5e91'}               3        4
#
#    personal cnt  etc cnt  knowledge cnt  Years  \
# 0             2        6             15      4
# 1             2        6              1      3
# 2             1        4              2      9
# 3             3        1              3      8
# 4             3        1              3      3
#
#                                               School
# 0  University of California, Irvine Division of C...
# 1                               University of Surrey
# 2              University of California, Los Angeles
# 3                 University of California, Berkeley
# 4  University of Pittsburgh College of Business A...
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Degree

# %%
def get_degree(ser):
    if len(ser)==0:
        deg = 'Not Specification'
    else:
        deg = ser[0]['Degree']
    return deg

# %%
df['Degree'] = df['Education'].apply(lambda x:get_degree(x))
df.iloc[5,-1]
# Out:
# 'Master of Fine Arts (MFA) Communication Design '

# %%
## 수작업을 위해 degree만 빼와서 작업해보자
df_deg = df[['Degree']]
df_deg['punct'] = df_deg['Degree'].apply(lambda x:remove_punct(x.replace(' ','').lower()))
#df_deg['tokn']  = df_deg['punct'].apply(lambda x:tokenize(x))
#df_deg['stp']   = df_deg['tokn'].apply(lambda x:remove_stopwords(x))
#df_deg['lemm']  = df_deg['stp'].apply(lambda x:lemmatizing(x))
df_deg['two'] = df_deg['punct'].apply(lambda x:x[:2])
df_deg.head()
# Out:
#                                               Degree  \
# 0  Certificate of Data Analytics Management Infor...
# 1           Bachelor of Science - BS Field Of Study
# 2                                East Asian Studies
# 3
# 4  Bachelor of Business Administration - BBA Mark...
#
#                                                punct two
# 0  certificateofdataanalyticsmanagementinformatio...  ce
# 1                    bachelorofsciencebsfieldofstudy  ba
# 2                                   eastasianstudies  ea
# 3
# 4  bachelorofbusinessadministrationbbamarketingdi...  ba

# %%
df_deg[df_deg['two']=='ec'][['Degree','two']]
# Out:
#                                                  Degree two
# 69                  Economics Bachelor of Arts (B.A.)    ec
# 75            Economics and Legal Studies double major   ec
# 85                                          Economics    ec
# 207                                          Economics   ec
# 218                                          Economics   ec
# 231           Economics and Business & Administrations   ec
# 248                                      Economics 3.88  ec
# 249                             Economics, Art History   ec
# 305              Ecomonics and Political Science Senior  ec
# 314                                          Economics   ec
# 368                       Economics, IMC, Korean Minor   ec
# 488            Economics and Mind, Brain, and Behavior   ec
# 692                  Economics Business Administration   ec
# 759                   Economics Japanese Studies Minor   ec
# 1033          Economics and Asian American Studies  3.8  ec
# 317                       Economics, Cognitive Science   ec
# 339                                          Economics   ec
# 387                               Economics Second Year  ec
# 476    Economics and International Relations, Englis...  ec
# 491    Economics, Operations Research Management Sci...  ec

# %%
## no는 degree입력 안한사람들
##   는 입력은 했는데 space로 입력했나봄

# %%
# kind_deg = df_deg['two'].value_counts()
# kind_deg 'ma' 'ba' 'no' 'do' 
def deg_class(tr):
    if len(tr)==0 or tr[0]=='n':
        ret = 'Not Specification'
    elif tr[0]=='b':
        ret = 'Bachelor'
    elif tr[0]=='m':
        ret = 'Master'
    elif tr[0]=='d' or tr=='ph':
        ret = 'Ph.D'
    else:
        ret = 'ETC'
    return ret

# %%
df['Degree'] = df_deg['two'].apply(lambda x:deg_class(x))

# %% [markdown]
# ## Location

# %%
city_state = pd.read_csv('city_state.csv')
city_state
# Out:
#               city                 state             state_s        city_s
# 0         New York              New York             newyork       newyork
# 1      Los Angeles            California          california    losangeles
# 2          Chicago              Illinois            illinois       chicago
# 3          Houston                 Texas               texas       houston
# 4          Phoenix               Arizona             arizona       phoenix
# 5     Philadelphia          Pennsylvania        pennsylvania  philadelphia
# 6      San Antonio                 Texas               texas    sanantonio
# 7        San Diego            California          california      sandiego
# 8           Dallas                 Texas               texas        dallas
# 9         San Jose            California          california       sanjose
# 10          Austin                 Texas               texas        austin
# 11    Jacksonville               Florida             florida  jacksonville
# 12      Fort Worth                 Texas               texas     fortworth
# 13        Columbus                  Ohio                ohio      columbus
# 14   San Francisco            California          california  sanfrancisco
# 15       Charlotte        North Carolina       northcarolina     charlotte
# 16    Indianapolis               Indiana             indiana  indianapolis
# 17         Seattle            Washington          washington       seattle
# 18          Denver              Colorado            colorado        denver
# 19      Washington  District of Columbia  districtofcolumbia    washington
# 20          Boston         Massachusetts       massachusetts        boston
# 21         El Paso                 Texas               texas        elpaso
# 22         Detroit              Michigan            michigan       detroit
# 23       Nashville             Tennessee           tennessee     nashville
# 24        Portland                Oregon              oregon      portland
# 25         Memphis             Tennessee           tennessee       memphis
# 26   Oklahoma City              Oklahoma            oklahoma  oklahomacity
# 27       Las Vegas                Nevada              nevada      lasvegas
# 28      Louisville              Kentucky            kentucky    louisville
# 29       Baltimore              Maryland            maryland     baltimore
# ..             ...                   ...                 ...           ...
# 284        Greeley              Colorado            colorado       greeley
# 285      Daly City            California          california      dalycity
# 286       Meridian                 Idaho               idaho      meridian
# 287     Lewisville                 Texas               texas    lewisville
# 288          Davie               Florida             florida         davie
# 289    West Covina            California          california    westcovina
# 290    League City                 Texas               texas    leaguecity
# 291          Tyler                 Texas               texas         tyler
# 292        Norwalk            California          california       norwalk
# 293      San Mateo            California          california      sanmateo
# 294      Green Bay             Wisconsin           wisconsin      greenbay
# 295  Wichita Falls                 Texas               texas  wichitafalls
# 296         Sparks                Nevada              nevada        sparks
# 297       Lakewood            New Jersey           newjersey      lakewood
# 298        Burbank            California          california       burbank
# 299         Rialto            California          california        rialto
# 300          Allen                 Texas               texas         allen
# 301       El Cajon            California          california       elcajon
# 302     Las Cruces            New Mexico           newmexico     lascruces
# 303         Renton            Washington          washington        renton
# 304      Davenport                  Iowa                iowa     davenport
# 305     South Bend               Indiana             indiana     southbend
# 306          Vista            California          california         vista
# 307     Tuscaloosa               Alabama             alabama    tuscaloosa
# 308        Clinton              Michigan            michigan       clinton
# 309         Edison            New Jersey           newjersey        edison
# 310     Woodbridge            New Jersey           newjersey    woodbridge
# 311     San Angelo                 Texas               texas     sanangelo
# 312        Kenosha             Wisconsin           wisconsin       kenosha
# 313      Vacaville            California          california     vacaville
#
# [314 rows x 4 columns]

# %%
df_loc = pd.DataFrame(df['Location'].str.replace(' ','').str.replace(',','').str.lower())

# %%
df['State'] = None
df['City'] = None

# %%
for i in range(len(df_loc)):
    for j in range(len(city_state)):
        if city_state['city_s'][j] in df_loc['Location'][i]:
            df['City'][i] = city_state['city'][j]
            df['State'][i] = city_state['state'][j]
            break
            
        elif city_state['state_s'][j] in df_loc['Location'][i]:
            df['State'][i] = city_state['state'][j]
            break
df.head()
