# %%
# 그래프에서 한글표현을 위해 폰트를 설치합니다.
# %config InlineBackend.figure_format = 'retina'

# !apt -qq -y install fonts-nanum > /dev/null
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
from sklearn.datasets import make_moons
import pandas as pd

# %%
# 데이터 불러오기
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    id             date     price  ...     long  sqft_living15  sqft_lot15
# 0   0  20141013T000000  221900.0  ... -122.257           1340        5650
# 1   1  20150225T000000  180000.0  ... -122.233           2720        8062
# 2   2  20150218T000000  510000.0  ... -122.045           1800        7503
# 3   3  20140627T000000  257500.0  ... -122.327           2238        6819
# 4   4  20150115T000000  291850.0  ... -122.315           1650        9711
#
# [5 rows x 21 columns]

# %%
test.head()
# Out:
#       id             date  bedrooms  ...     long  sqft_living15  sqft_lot15
# 0  15035  20141209T000000         3  ... -122.319           1690        7639
# 1  15036  20141209T000000         4  ... -122.393           1360        5000
# 2  15037  20140512T000000         4  ... -122.005           4760      101930
# 3  15038  20150415T000000         3  ... -122.337           1780        8113
# 4  15039  20150312T000000         3  ... -122.031           2390        7570
#
# [5 rows x 20 columns]

# %%
train.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# 데이터 행열 확인
print(train.shape)
print(test.shape)
# Out:
# (15035, 21)
# (6468, 20)

# %%
# 결측치 확인
print(train.isnull().sum())
print("-"*20)
print(test.isnull().sum())
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64
# --------------------
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
X_all = train.drop(['price'], axis=1)
y = train['price']

# %%
sel = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot']

X = X_all[sel]
y = train['price']

# %%
# 데이터 split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    random_state=42)

# %%
# 모델 만들기
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
forest = RandomForestRegressor(n_estimators=5, random_state=2)

# %%
# 모델 학습
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=None,
#                       oob_score=False, random_state=2, verbose=0,
#                       warm_start=False)

# %%
print(forest.estimators_)
# Out:
# [DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=1872583848, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=794921487, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=111352301, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=1853453896, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=213298710, splitter='best')]

# %%
# 변수의 중요도
print(forest.feature_importances_)
# Out:
# [0.03934276 0.07187087 0.6741707  0.21461568]

# %%
sum(forest.feature_importances_)
# Out:
# 1.0

# %%
# 변수의 중요도 그래프 찍기
import matplotlib.pyplot as plt
import numpy as np

def plot_feature_importances_cancer(model, dataset):
 n_features = dataset.shape[1]
 plt.barh(range(n_features), model.feature_importances_, align='center')
 plt.yticks(np.arange(n_features), dataset.columns)
 plt.xlabel("특성 중요도")
 plt.ylabel("특성")
 plt.ylim(-1, n_features)

plot_feature_importances_cancer(forest, X)

# %% [markdown]
# ## 실습
# 모델 50개 만들어 보기

# %%
# 모델 만들기
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
forest20 = RandomForestRegressor(n_estimators=20, random_state=2, max_depth=3)

# %%
# 모델 학습
forest20.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=3,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=20,
#                       n_jobs=None, oob_score=False, random_state=2, verbose=0,
#                       warm_start=False)

# %%
# 변수의 중요도 그래프 찍기
import matplotlib.pyplot as plt
import numpy as np

def plot_feature_importances_cancer(model, dataset):
 n_features = dataset.shape[1]
 plt.barh(range(n_features), model.feature_importances_, align='center')
 plt.yticks(np.arange(n_features), dataset.columns)
 plt.xlabel("특성 중요도")
 plt.ylabel("특성")
 plt.ylim(-1, n_features)

plot_feature_importances_cancer(forest20, X)

# %%
# 20 모델에 대한 평가
cnt = 1
for model in forest20.estimators_:
  model.fit(X_train, y_train)

  if cnt % 5 == 0:
    print("훈련 세트 정확도 : {:.3f}".format(model.score(X_train, y_train)))
    print("테스트 세트 정확도 : {:.3f}".format(model.score(X_test, y_test)))
  cnt += 1
# Out:
# 훈련 세트 정확도 : 0.559
# 테스트 세트 정확도 : 0.432
# 훈련 세트 정확도 : 0.559
# 테스트 세트 정확도 : 0.432
# 훈련 세트 정확도 : 0.559
# 테스트 세트 정확도 : 0.432
# 훈련 세트 정확도 : 0.559
# 테스트 세트 정확도 : 0.432

# %%
# 예측
pred = forest.predict(X_test)
pred
# Out:
# array([322990., 338498., 318200., ..., 224600., 450960., 329990.])

# %%
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot
# 2021          3       2.50         1480      7200
# 12670         4       1.50         1920     11595
# 4359          3       1.50         1410      3600
# 10556         2       1.00          790      7500
# 3468          4       2.25         2130      7172
# 10084         3       1.75         1510      8385
# 927           3       2.25         1580      6561
# 11672         4       2.25         2100      7350
# 5180          3       1.75         1910      8329
# 9045          3       2.50         2070      8400
# 12569         3       2.50         2440      7419
# 12960         1       1.00         1310      8667
# 5714          5       2.75         1340     11583
# 7770          4       1.75         2520      8442
# 2595          4       1.00         1070      7467
# 10075         3       2.50         1800      7318
# 5405          4       1.75         2260      6600
# 11716         5       2.25         2230      9600
# 3532          3       2.50         1740      1279
# 1006          2       1.00         1050      5671
# 11256         4       2.50         2980      5896
# 6759          4       2.50         2080      5191
# 4554          3       2.25         1900      8125
# 14716         2       2.50         1320      1395
# 5135          3       2.50         2570      5500
# 2019          3       2.00         1180      1800
# 15025         4       3.25         3410     10125
# 3341          4       2.50         2320      4254
# 7046          2       2.25         1290      2436
# 7677          3       1.75         1830     10000
# ...         ...        ...          ...       ...
# 1463          4       2.25         2020      8424
# 6005          3       2.50         1540      7739
# 3859          4       1.75         1770     12462
# 7887          3       1.50         2700     24539
# 9548          2       2.00         1340      7605
# 12214         2       1.00         1060      5754
# 2287          2       1.00          810      7980
# 7573          2       2.00         1600     64468
# 3351          5       1.00         1860      3040
# 13345         3       2.50         1960     47044
# 965           3       1.75         1290      3870
# 14719         3       3.25         1710      1960
# 6427          4       3.25         3470      5222
# 2252          6       3.00         4050     36171
# 8723          3       2.75         1400      7880
# 2578          3       2.50         3300     11570
# 438           3       2.50         1610      2937
# 12435         2       1.00          760      7114
# 12828         4       2.00         2060      6000
# 1614          4       2.50         4250     19387
# 4822          3       2.50         2320     98445
# 9002          2       1.00          870      7020
# 13758         3       2.50         2230      3939
# 5156          3       3.00         3920     13085
# 13332         3       2.25         2990    216057
# 13139         4       2.50         2800      5368
# 467           2       1.00          890      3060
# 10108         2       1.00          720      5160
# 3751          4       2.50         2500      9654
# 4635          4       2.50         2240      6920
#
# [3759 rows x 4 columns]

# %%
sample = pd.read_csv('sample_submission.csv')
sample.head()
# Out:
#       id   price
# 0  15035  100000
# 1  15036  100000
# 2  15037  100000
# 3  15038  100000
# 4  15039  100000

# %%
print(sample.shape)
print(pred.shape)
print(X_train.shape)
# Out:
# (6468, 2)
# (3759,)
# (11276, 4)

# %%
sample['price']=pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-a50a6586d5d6> in <module>()
# ----> 1 sample['price']=pred
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# -> 3630             value = sanitize_index(value, self.index, copy=False)
#    3631             if not isinstance(value, (np.ndarray, Index)):
#    3632                 if isinstance(value, list) and len(value) > 0:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     517
#     518     if len(data) != len(index):
# --> 519         raise ValueError('Length of values does not match length of index')
#     520
#     521     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index
