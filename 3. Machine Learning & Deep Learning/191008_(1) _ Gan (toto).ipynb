# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)
# Out:
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz

# %%
n_input = 28 * 28
n_noise = 128

n_hidden = 256  # 은닉층 노드수

# 
total_epoch = 100
batch_size = 100    # 배치 사이즈
learning_rate = 0.0002  # 학습률

# %%
X = tf.placeholder(tf.float32, [None, n_input])
# 생성망에 들어갈 입력 데이터(정규분포를 따르는 128개의 데이터)
Z = tf.placeholder(tf.float32, [None, n_noise])

# %% [markdown]
# ## 생성자 신경망
# * W
# * b

# %%
import numpy as np

# %%
# 생성자 신경망 (입력층 -> 은닉층)
G_W1 = tf.Variable(tf.random_normal([n_noise,n_hidden], stddev=0.01))
G_b1 = tf.Variable(tf.zeros([n_hidden]))

# 생성자 신경망 (은닉층 -> 출력층)
G_W2 = tf.Variable(tf.random_normal([n_hidden , n_input], stddev=0.01))
G_b2 = tf.Variable(tf.zeros([n_input]))

# %%
# (판별망) 입력층 -> 은닉층으로 
D_W1 = tf.Variable(tf.random_normal([n_input,n_hidden], stddev=0.01))
D_b1 = tf.Variable(tf.zeros([n_hidden]))

# 은닉층에서 출력층으로
D_W2 = tf.Variable(tf.random_normal([n_hidden , 1], stddev=0.01))
D_b2 = tf.Variable(tf.zeros([1]))

# %% [markdown]
# ## 노이즈 데이터 발생을 위한 노이즈 생성 함수
# * def get_noise(데이터 개수, 노이즈 개수)

# %%
def get_noise(batch_size, n_noise):
  return np.random.normal(size=(batch_size, n_noise))

# %% [markdown]
# ### 생성자와 판별자의 신경망을 직접 구성

# %%
def generator(noise_z):
  hidden = tf.nn.relu( tf.matmul(noise_z, G_W1) + G_b1)
  output = tf.nn.sigmoid( tf.matmul(hidden, G_W2 ) + G_b2 )
  
  return output

# %%
def discriminator(inputs ):
  hidden = tf.nn.relu( tf.matmul(inputs, D_W1) + D_b1)
  output = tf.nn.sigmoid( tf.matmul(hidden, D_W2 ) + D_b2 )
  
  return output

# %%
# 생성자 신경망
G = generator(Z)

# 판별자 신경망
D_fake = discriminator(G)

# 진짜 이미지 
D_real = discriminator(X)

# %% [markdown]
# ### 비용함수, 최적화 함수

# %%
# 경찰관의 성능 -> 가능한 높은 값.
loss_D = tf.reduce_mean(tf.log(D_real) + tf.log(1-D_fake))

# 위조지폐범의 성능 - 가능한 높은 값
loss_G = tf.reduce_mean(tf.log(D_fake))

# %%
# 사용하는 변수 리스트화
D_var_list = [D_W1, D_b1, D_W2, D_b2]
G_var_list = [G_W1, G_b1, G_W2, G_b2]

# %%
### 오차 최소화가 아니라..
### GAN은 loss_D와 loss_G를 최대화시키는 것이 목표다.
train_D = tf.train.AdamOptimizer(learning_rate).minimize(-loss_D, var_list=D_var_list)
train_G = tf.train.AdamOptimizer(learning_rate).minimize(-loss_G, var_list=G_var_list)

# %%
### 모델 학습

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

total_batch = int(mnist.train.num_examples/batch_size)
loss_val_D, loss_val_G = 0, 0

# %%
# !mkdir samples
# Out:
# mkdir: cannot create directory ‘samples’: File exists

# %%
for epoch in range(20):
  for i in range(total_batch):
    batch_xs, batch_ys = mnist.train.next_batch(batch_size) # 판별망의 데이터 
    noise = get_noise(batch_size, n_noise) # 생성망에 들어가는 입력
    
    _, loss_val_D = sess.run([train_D, loss_D], 
                             feed_dict={X:batch_xs, Z:noise})
    _, loss_val_G = sess.run([train_G, loss_G],
                             feed_dict={Z:noise})
    
  print("Epoch : {}, 판별망의 성능 : {:.4f}, 생성망의 성능 : {:.4f}".format(epoch, 
                                                           loss_val_D,
                                                           loss_val_G))
print("최적화 완료!")
# Out:
# Epoch : 0, 판별망의 성능 : -0.5687, 생성망의 성능 : -1.9597
# Epoch : 1, 판별망의 성능 : -0.2203, 생성망의 성능 : -2.7662
# Epoch : 2, 판별망의 성능 : -0.1002, 생성망의 성능 : -3.2309
# Epoch : 3, 판별망의 성능 : -0.4638, 생성망의 성능 : -1.5879
# Epoch : 4, 판별망의 성능 : -0.3022, 생성망의 성능 : -1.9303
# Epoch : 5, 판별망의 성능 : -0.2051, 생성망의 성능 : -2.5569
# Epoch : 6, 판별망의 성능 : -0.2254, 생성망의 성능 : -3.0181
# Epoch : 7, 판별망의 성능 : -0.2982, 생성망의 성능 : -2.0422
# Epoch : 8, 판별망의 성능 : -0.3580, 생성망의 성능 : -2.4170
# Epoch : 9, 판별망의 성능 : -0.4028, 생성망의 성능 : -2.2400
# Epoch : 10, 판별망의 성능 : -0.4981, 생성망의 성능 : -2.3192
# Epoch : 11, 판별망의 성능 : -0.4038, 생성망의 성능 : -2.4497
# Epoch : 12, 판별망의 성능 : -0.4089, 생성망의 성능 : -2.2973
# Epoch : 13, 판별망의 성능 : -0.3800, 생성망의 성능 : -2.4972
# Epoch : 14, 판별망의 성능 : -0.2198, 생성망의 성능 : -3.0342
# Epoch : 15, 판별망의 성능 : -0.1962, 생성망의 성능 : -3.3134
# Epoch : 16, 판별망의 성능 : -0.1958, 생성망의 성능 : -3.2826
# Epoch : 17, 판별망의 성능 : -0.2768, 생성망의 성능 : -2.5022
# Epoch : 18, 판별망의 성능 : -0.2844, 생성망의 성능 : -3.0401
# Epoch : 19, 판별망의 성능 : -0.2672, 생성망의 성능 : -2.9832
# 최적화 완료!

# %%
# !mkdir samples

# %%
for epoch in range(100):
  for i in range(total_batch):
    batch_xs, batch_ys = mnist.train.next_batch(batch_size) # 판별망의 데이터 
    noise = get_noise(batch_size, n_noise) # 생성망에 들어가는 입력
    
    _, loss_val_D = sess.run([train_D, loss_D], 
                             feed_dict={X:batch_xs, Z:noise})
    _, loss_val_G = sess.run([train_G, loss_G],
                             feed_dict={Z:noise})
    

  if epoch == 0 or (epoch + 1) % 10 == 0:
    sample_size = 10
    noise = get_noise(sample_size, n_noise) # 노이즈 생성.
    samples = sess.run(G, feed_dict={Z: noise})
    fig, ax = plt.subplots(1, sample_size, figsize=(sample_size, 1))
    
    for i in range(sample_size):
      ax[i].set_axis_off()
      ax[i].imshow(np.reshape(samples[i], (28, 28)))
      
    plt.savefig('samples/{}.png'.format(str(epoch).zfill(3)), bbox_inches='tight')
    plt.close(fig)

  print("Epoch : {}, 판별망의 성능 : {:.4f}, 생성망의 성능 : {:.4f}".format(epoch, 
                                                           loss_val_D,
                                                           loss_val_G))
    
print("최적화 완료!")
# Out:
# Epoch : 0, 판별망의 성능 : -0.6370, 생성망의 성능 : -2.5585
# Epoch : 1, 판별망의 성능 : -0.5450, 생성망의 성능 : -2.3284
# Epoch : 2, 판별망의 성능 : -0.3675, 생성망의 성능 : -2.7296
# Epoch : 3, 판별망의 성능 : -0.6592, 생성망의 성능 : -2.3626
# Epoch : 4, 판별망의 성능 : -0.5698, 생성망의 성능 : -2.4085
# Epoch : 5, 판별망의 성능 : -0.5405, 생성망의 성능 : -2.3753
# Epoch : 6, 판별망의 성능 : -0.3906, 생성망의 성능 : -2.8932
# Epoch : 7, 판별망의 성능 : -0.6432, 생성망의 성능 : -2.3595
# Epoch : 8, 판별망의 성능 : -0.5569, 생성망의 성능 : -2.3019
# Epoch : 9, 판별망의 성능 : -0.5457, 생성망의 성능 : -2.5655
# Epoch : 10, 판별망의 성능 : -0.4420, 생성망의 성능 : -2.4862
# Epoch : 11, 판별망의 성능 : -0.6324, 생성망의 성능 : -2.7567
# Epoch : 12, 판별망의 성능 : -0.5169, 생성망의 성능 : -2.4861
# Epoch : 13, 판별망의 성능 : -0.4569, 생성망의 성능 : -2.5867
# Epoch : 14, 판별망의 성능 : -0.5456, 생성망의 성능 : -2.3996
# Epoch : 15, 판별망의 성능 : -0.5891, 생성망의 성능 : -2.2194
# Epoch : 16, 판별망의 성능 : -0.5884, 생성망의 성능 : -2.3643
# Epoch : 17, 판별망의 성능 : -0.5777, 생성망의 성능 : -2.2142
# Epoch : 18, 판별망의 성능 : -0.5056, 생성망의 성능 : -2.4330
# Epoch : 19, 판별망의 성능 : -0.6643, 생성망의 성능 : -2.1772
# Epoch : 20, 판별망의 성능 : -0.6381, 생성망의 성능 : -2.5275
# Epoch : 21, 판별망의 성능 : -0.6041, 생성망의 성능 : -1.8930
# Epoch : 22, 판별망의 성능 : -0.6258, 생성망의 성능 : -2.4455
# Epoch : 23, 판별망의 성능 : -0.6142, 생성망의 성능 : -2.1481
# Epoch : 24, 판별망의 성능 : -0.6333, 생성망의 성능 : -2.1165
# Epoch : 25, 판별망의 성능 : -0.6153, 생성망의 성능 : -2.0954
# Epoch : 26, 판별망의 성능 : -0.6036, 생성망의 성능 : -2.1693
# Epoch : 27, 판별망의 성능 : -0.7070, 생성망의 성능 : -1.9024
# Epoch : 28, 판별망의 성능 : -0.5311, 생성망의 성능 : -2.2241
# Epoch : 29, 판별망의 성능 : -0.4551, 생성망의 성능 : -2.3873
# Epoch : 30, 판별망의 성능 : -0.8003, 생성망의 성능 : -2.0747
# Epoch : 31, 판별망의 성능 : -0.5685, 생성망의 성능 : -1.9251
# Epoch : 32, 판별망의 성능 : -0.6877, 생성망의 성능 : -2.1215
# Epoch : 33, 판별망의 성능 : -0.6501, 생성망의 성능 : -2.0169
# Epoch : 34, 판별망의 성능 : -0.6788, 생성망의 성능 : -2.0893
# Epoch : 35, 판별망의 성능 : -0.7194, 생성망의 성능 : -2.1504
# Epoch : 36, 판별망의 성능 : -0.6425, 생성망의 성능 : -2.3981
# Epoch : 37, 판별망의 성능 : -0.7110, 생성망의 성능 : -1.9132
# Epoch : 38, 판별망의 성능 : -0.6863, 생성망의 성능 : -2.0913
# Epoch : 39, 판별망의 성능 : -0.6648, 생성망의 성능 : -2.1234
# Epoch : 40, 판별망의 성능 : -0.6243, 생성망의 성능 : -2.2469
# Epoch : 41, 판별망의 성능 : -0.7583, 생성망의 성능 : -2.2576
# Epoch : 42, 판별망의 성능 : -0.7469, 생성망의 성능 : -2.1103
# Epoch : 43, 판별망의 성능 : -0.5810, 생성망의 성능 : -2.2252
# Epoch : 44, 판별망의 성능 : -0.7923, 생성망의 성능 : -2.2879
# Epoch : 45, 판별망의 성능 : -0.5800, 생성망의 성능 : -2.0240
# Epoch : 46, 판별망의 성능 : -0.5762, 생성망의 성능 : -2.1134
# Epoch : 47, 판별망의 성능 : -0.7232, 생성망의 성능 : -2.1752
# Epoch : 48, 판별망의 성능 : -0.6035, 생성망의 성능 : -2.3684
# Epoch : 49, 판별망의 성능 : -0.6053, 생성망의 성능 : -2.0018
# Epoch : 50, 판별망의 성능 : -0.6961, 생성망의 성능 : -2.0743
# Epoch : 51, 판별망의 성능 : -0.7400, 생성망의 성능 : -2.0424
# Epoch : 52, 판별망의 성능 : -0.6523, 생성망의 성능 : -1.9526
# Epoch : 53, 판별망의 성능 : -0.5132, 생성망의 성능 : -2.4451
# Epoch : 54, 판별망의 성능 : -0.7375, 생성망의 성능 : -2.1657
# Epoch : 55, 판별망의 성능 : -0.6681, 생성망의 성능 : -2.3376
# Epoch : 56, 판별망의 성능 : -0.7314, 생성망의 성능 : -2.0791
# Epoch : 57, 판별망의 성능 : -0.7885, 생성망의 성능 : -1.7246
# Epoch : 58, 판별망의 성능 : -0.6323, 생성망의 성능 : -2.0319
# Epoch : 59, 판별망의 성능 : -0.7226, 생성망의 성능 : -2.0853
# Epoch : 60, 판별망의 성능 : -0.6364, 생성망의 성능 : -1.9587
# Epoch : 61, 판별망의 성능 : -0.5509, 생성망의 성능 : -2.2912
# Epoch : 62, 판별망의 성능 : -0.6783, 생성망의 성능 : -1.9713
# Epoch : 63, 판별망의 성능 : -0.5857, 생성망의 성능 : -2.1647
# Epoch : 64, 판별망의 성능 : -0.6054, 생성망의 성능 : -2.2612
# Epoch : 65, 판별망의 성능 : -0.7627, 생성망의 성능 : -2.0004
# Epoch : 66, 판별망의 성능 : -0.5716, 생성망의 성능 : -2.2819
# Epoch : 67, 판별망의 성능 : -0.6719, 생성망의 성능 : -2.3033
# Epoch : 68, 판별망의 성능 : -0.5494, 생성망의 성능 : -2.1862
# Epoch : 69, 판별망의 성능 : -0.5182, 생성망의 성능 : -2.6951
# Epoch : 70, 판별망의 성능 : -0.6430, 생성망의 성능 : -2.1379
# Epoch : 71, 판별망의 성능 : -0.5594, 생성망의 성능 : -2.3726
# Epoch : 72, 판별망의 성능 : -0.6141, 생성망의 성능 : -2.4777
# Epoch : 73, 판별망의 성능 : -0.6516, 생성망의 성능 : -2.2865
# Epoch : 74, 판별망의 성능 : -0.5902, 생성망의 성능 : -2.5585
# Epoch : 75, 판별망의 성능 : -0.5211, 생성망의 성능 : -2.4487
# Epoch : 76, 판별망의 성능 : -0.4774, 생성망의 성능 : -2.3448
# Epoch : 77, 판별망의 성능 : -0.5726, 생성망의 성능 : -2.1745
# Epoch : 78, 판별망의 성능 : -0.5233, 생성망의 성능 : -2.2374
# Epoch : 79, 판별망의 성능 : -0.7513, 생성망의 성능 : -2.2652
# Epoch : 80, 판별망의 성능 : -0.5955, 생성망의 성능 : -2.6293
# Epoch : 81, 판별망의 성능 : -0.5665, 생성망의 성능 : -2.6874
# Epoch : 82, 판별망의 성능 : -0.5254, 생성망의 성능 : -2.5256
# Epoch : 83, 판별망의 성능 : -0.7083, 생성망의 성능 : -2.2612
# Epoch : 84, 판별망의 성능 : -0.5281, 생성망의 성능 : -2.4953
# Epoch : 85, 판별망의 성능 : -0.6343, 생성망의 성능 : -2.1944
# Epoch : 86, 판별망의 성능 : -0.5559, 생성망의 성능 : -2.3457
# Epoch : 87, 판별망의 성능 : -0.5814, 생성망의 성능 : -2.3850
# Epoch : 88, 판별망의 성능 : -0.5837, 생성망의 성능 : -2.4364
# Epoch : 89, 판별망의 성능 : -0.4816, 생성망의 성능 : -2.3671
# Epoch : 90, 판별망의 성능 : -0.4602, 생성망의 성능 : -2.6607
# Epoch : 91, 판별망의 성능 : -0.6078, 생성망의 성능 : -2.6844
# Epoch : 92, 판별망의 성능 : -0.5012, 생성망의 성능 : -2.5022
# Epoch : 93, 판별망의 성능 : -0.6639, 생성망의 성능 : -2.2072
# Epoch : 94, 판별망의 성능 : -0.4542, 생성망의 성능 : -2.5622
# Epoch : 95, 판별망의 성능 : -0.6304, 생성망의 성능 : -2.4741
# Epoch : 96, 판별망의 성능 : -0.5095, 생성망의 성능 : -2.3975
# Epoch : 97, 판별망의 성능 : -0.5549, 생성망의 성능 : -2.3713
# Epoch : 98, 판별망의 성능 : -0.6325, 생성망의 성능 : -2.3468
# Epoch : 99, 판별망의 성능 : -0.5756, 생성망의 성능 : -2.5530
# 최적화 완료!

# %%
#범주가 여러개일때 쓰는 함수 소프트 맥스 sigmoid함수는 임계값을 정해서 0과 1을 갖는지 찾는다. 
#비용함수 활성화함수(relu sig) 최적화함수
