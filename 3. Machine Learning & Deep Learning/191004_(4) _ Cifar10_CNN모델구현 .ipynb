# %% [markdown]
# > Cifar10 데이터 셋으로 신경망 모델 구현
# * 실제 이미지를 이용하여 예측 수행

# %%
from keras.datasets import cifar10
import keras
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# lable names
label_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)
# (10000, 1)

# %%
X_train_n = X_train.copy()
y_train_n = y_train.copy()

# %%
print('label = {}'.format(y_train[0:15,0]))
# Out:
# label = [6 9 9 4 1 1 2 7 8 3 4 7 7 2 9]

# %%
print('label = {}'.format(label_names[y_train[0,0]]))
# Out:
# label = frog

# %%
# label_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

print('label = {}'.format(y_train[0:15,0]))


fix, ax = plt.subplots(2,5,figsize=(10,5))

for i in range(5):
  ax[0][i].imshow(np.reshape(X_train[i], (32,32,3)))
  ax[1][i].imshow(np.reshape(X_train[i+5], (32,32,3)))

plt.show()
# Out:
# label = [6 9 9 4 1 1 2 7 8 3 4 7 7 2 9]

# %%
num_classes = 10

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
print(y_train.shape)
# Out:
# (50000, 10)

# %%
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
Y = tf.placeholder(tf.float32, [None, 10])

# %%
W1 = tf.Variable(tf.random_normal([3,3,3,32], stddev=0.01))
L1 = tf.nn.conv2d(X, W1, strides=[1,1,1,1], padding='SAME')
L1 = tf.nn.relu(L1)
L1 = tf.nn.max_pool(L1, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
print(L1)
# Out:
# Tensor("MaxPool_20:0", shape=(?, 16, 16, 32), dtype=float32)

# %%
## 2번째 신경망 CONV 3*3 개수 64, 활성화 함수 relu, max_pool 2*2 strides 2
## 3번째 신경망 CONV 3*3 개수 128, 활성화 함수 relu, max_pool 2*2 strides 2

# %%
W2 = tf.Variable(tf.random_normal([3,3,32,64], stddev=0.01))
L2 = tf.nn.conv2d(L1, W2, strides=[1,1,1,1], padding='SAME')
L2 = tf.nn.relu(L2)
L2 = tf.nn.max_pool(L2, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
print(L2)
# Out:
# Tensor("MaxPool_21:0", shape=(?, 8, 8, 64), dtype=float32)

# %%
W3 = tf.Variable(tf.random_normal([3,3,64,128], stddev=0.01))
L3 = tf.nn.conv2d(L2, W3, strides=[1,1,1,1], padding='SAME')
L3 = tf.nn.relu(L3)
L3 = tf.nn.max_pool(L3, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
print(L3)
# Out:
# Tensor("MaxPool_22:0", shape=(?, 4, 4, 128), dtype=float32)

# %%
W4 = tf.Variable(tf.random_normal([4*4*128, 256], stddev=0.01))
L4 = tf.reshape(L3, [-1,4*4*128])
L4 = tf.matmul(L4, W4)
L4 = tf.nn.relu(L4) 
print(L4)
# Out:
# Tensor("Relu_27:0", shape=(?, 256), dtype=float32)

# %%
W5 = tf.Variable(tf.random_normal([256,10], stddev=0.01))
model=tf.matmul(L4, W5)
model
# Out:
# <tf.Tensor 'MatMul_11:0' shape=(?, 10) dtype=float32>

# %%
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=model, labels=Y))
optimizer = tf.train.AdamOptimizer(0.001).minimize(cost)

# %%
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %%
batch_size = 100
total_batch = int(len(X_train)/batch_size)
print(total_batch)
epochs = 20
# Out:
# 500

# %%
def next_batch(start, num, data, labels):
  data_X = data[start:start+num]
  data_y = labels[start:start+num]

  return np.asarray(data_X), np.asarray(data_y)

# %%
print(X_train.shape, y_train.shape)
batch_x, batch_y = next_batch(0, 10, X_train, y_train)
print(batch_x.shape, batch_y.shape)
# Out:
# (50000, 32, 32, 3) (50000, 10)
# (10, 32, 32, 3) (10, 10)

# %%
total_cost = 0
epoch = 0
print('전체 입력 데이터 : {}'.format(X_train.shape))
print('전체 출력 데이터 : {}\n'.format(y_train.shape))

for epoch in range(51):
  total_cost = 0

  for i in range(total_batch):
    batch_xs, batch_ys = next_batch(batch_size*i, batch_size, X_train, y_train)

    _, cost_val = sess.run([optimizer, cost], feed_dict={X: batch_xs, Y: batch_ys})
    total_cost += cost_val

    if (i==0 or i==total_batch-1):
      print('data_step = {}, Avg. cost = {:.3f}'.format(i, cost_val))
  
  print('epoch: {} total.cost = {:.3f}'.format(epoch+1, total_cost))
  print('-------------------------------------------------------')
# Out:
# 전체 입력 데이터 : (50000, 32, 32, 3)
# 전체 출력 데이터 : (50000, 10)
#
# data_step = 0, Avg. cost = 2.301
# data_step = 499, Avg. cost = 1.348
# epoch: 1 total.cost = 817.894
# -------------------------------------------------------
# data_step = 0, Avg. cost = 1.121
# data_step = 499, Avg. cost = 1.217
# epoch: 2 total.cost = 572.793
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.877
# data_step = 499, Avg. cost = 1.064
# epoch: 3 total.cost = 480.741
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.741
# data_step = 499, Avg. cost = 0.895
# epoch: 4 total.cost = 420.155
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.627
# data_step = 499, Avg. cost = 0.750
# epoch: 5 total.cost = 367.486
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.652
# data_step = 499, Avg. cost = 0.732
# epoch: 6 total.cost = 338.893
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.541
# data_step = 499, Avg. cost = 0.616
# epoch: 7 total.cost = 312.998
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.590
# data_step = 499, Avg. cost = 0.642
# epoch: 8 total.cost = 286.093
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.351
# data_step = 499, Avg. cost = 0.581
# epoch: 9 total.cost = 260.162
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.440
# data_step = 499, Avg. cost = 0.492
# epoch: 10 total.cost = 240.069
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.371
# data_step = 499, Avg. cost = 0.470
# epoch: 11 total.cost = 207.876
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.273
# data_step = 499, Avg. cost = 0.313
# epoch: 12 total.cost = 199.929
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.417
# data_step = 499, Avg. cost = 0.304
# epoch: 13 total.cost = 182.271
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.233
# data_step = 499, Avg. cost = 0.306
# epoch: 14 total.cost = 178.826
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.187
# data_step = 499, Avg. cost = 0.443
# epoch: 15 total.cost = 162.710
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.190
# data_step = 499, Avg. cost = 0.186
# epoch: 16 total.cost = 163.586
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.198
# data_step = 499, Avg. cost = 0.240
# epoch: 17 total.cost = 152.012
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.332
# data_step = 499, Avg. cost = 0.219
# epoch: 18 total.cost = 139.881
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.173
# data_step = 499, Avg. cost = 0.358
# epoch: 19 total.cost = 134.937
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.413
# data_step = 499, Avg. cost = 0.133
# epoch: 20 total.cost = 129.438
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.334
# data_step = 499, Avg. cost = 0.218
# epoch: 21 total.cost = 115.800
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.274
# data_step = 499, Avg. cost = 0.488
# epoch: 22 total.cost = 115.226
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.292
# data_step = 499, Avg. cost = 0.064
# epoch: 23 total.cost = 107.330
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.179
# data_step = 499, Avg. cost = 0.282
# epoch: 24 total.cost = 99.230
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.315
# data_step = 499, Avg. cost = 0.376
# epoch: 25 total.cost = 96.703
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.137
# data_step = 499, Avg. cost = 0.071
# epoch: 26 total.cost = 93.577
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.083
# data_step = 499, Avg. cost = 0.254
# epoch: 27 total.cost = 89.089
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.043
# data_step = 499, Avg. cost = 0.219
# epoch: 28 total.cost = 88.928
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.169
# data_step = 499, Avg. cost = 0.144
# epoch: 29 total.cost = 87.571
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.168
# data_step = 499, Avg. cost = 0.057
# epoch: 30 total.cost = 79.297
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.045
# data_step = 499, Avg. cost = 0.139
# epoch: 31 total.cost = 84.624
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.123
# data_step = 499, Avg. cost = 0.219
# epoch: 32 total.cost = 81.610
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.156
# data_step = 499, Avg. cost = 0.140
# epoch: 33 total.cost = 76.636
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.481
# data_step = 499, Avg. cost = 0.039
# epoch: 34 total.cost = 75.815
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.143
# data_step = 499, Avg. cost = 0.132
# epoch: 35 total.cost = 84.922
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.189
# data_step = 499, Avg. cost = 0.101
# epoch: 36 total.cost = 76.333
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.091
# data_step = 499, Avg. cost = 0.368
# epoch: 37 total.cost = 84.349
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.118
# data_step = 499, Avg. cost = 0.028
# epoch: 38 total.cost = 86.138
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.038
# data_step = 499, Avg. cost = 0.131
# epoch: 39 total.cost = 69.302
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.088
# data_step = 499, Avg. cost = 0.086
# epoch: 40 total.cost = 71.203
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.054
# data_step = 499, Avg. cost = 0.101
# epoch: 41 total.cost = 78.503
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.300
# data_step = 499, Avg. cost = 0.063
# epoch: 42 total.cost = 79.206
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.055
# data_step = 499, Avg. cost = 0.052
# epoch: 43 total.cost = 68.061
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.171
# data_step = 499, Avg. cost = 0.105
# epoch: 44 total.cost = 69.070
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.024
# data_step = 499, Avg. cost = 0.097
# epoch: 45 total.cost = 72.961
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.162
# data_step = 499, Avg. cost = 0.201
# epoch: 46 total.cost = 77.734
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.295
# data_step = 499, Avg. cost = 0.064
# epoch: 47 total.cost = 72.543
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.193
# data_step = 499, Avg. cost = 0.182
# epoch: 48 total.cost = 71.054
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.097
# data_step = 499, Avg. cost = 0.113
# epoch: 49 total.cost = 67.586
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.102
# data_step = 499, Avg. cost = 0.030
# epoch: 50 total.cost = 68.071
# -------------------------------------------------------
# data_step = 0, Avg. cost = 0.032
# data_step = 499, Avg. cost = 0.136
# epoch: 51 total.cost = 72.424
# -------------------------------------------------------

# %%
is_correct = tf.equal(tf.argmax(model, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))

print('train 정확도 : ', sess.run(accuracy, feed_dict = {X:X_train, Y:y_train}))
print('test 정확도 : ', sess.run(accuracy, feed_dict = {X:X_test, Y:y_test}))
# Out:
# train 정확도 :  0.94206
# test 정확도 :  0.661

# %% [markdown]
# ## 실제 검색 이미지를 이용한 예측

# %%
# label_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']

# %%
import cv2

# %%
img = cv2.imread('dog2.jpg')
print(img.shape)
# Out:
# (194, 259, 3)

# %%
plt.imshow(img)

# %%
image_w = 32
image_h = 32

img = cv2.resize(img, None, fx=image_w/img.shape[1], fy=image_h/img.shape[0])
img.shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(img)

# %%
# print(img.shape)
# print(img.reshape(-1,32,32,3).shape)
# Out:
# (32, 32, 3)
# (1, 32, 32, 3)

# %%
result = tf.argmax(model, 1)
idx = sess.run(result, feed_dict={X:img.reshape(-1,32,32,3)})
print('예측 레이블 : ', label_names[idx[0]])
# Out:
# 예측 레이블 :  dog
