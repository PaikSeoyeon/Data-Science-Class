# %%
import tensorflow as tf

# %%
x_data =[1,2,3,4,5]
y_data = [10,20,30,40,50]

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

# %%
print(W)
# Out:
# <tf.Variable 'Variable:0' shape=(1,) dtype=float32_ref>

# %%
print(b)
# Out:
# <tf.Variable 'Variable_1:0' shape=(1,) dtype=float32_ref>

# %%
X = tf.placeholder(tf.float32, name='X')
Y = tf.placeholder(tf.float32, name='Y')
print(X)
print(Y)
# Out:
# Tensor("X_1:0", dtype=float32)
# Tensor("Y:0", dtype=float32)

# %%
score = W*X + b

# %%
loss = tf.reduce_mean(tf.square(score-y_data))
loss
# Out:
# <tf.Tensor 'Mean_1:0' shape=() dtype=float32>

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train_op = optimizer.minimize(loss)
train_op
# Out:
# <tf.Operation 'GradientDescent' type=NoOp>

# %%
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())

  for step in range(100):
    _, loss_val = sess.run([train_op, loss], feed_dict={X:x_data, Y:y_data})
    print(step, 'Loss = %-10.5f' % loss_val, 'W = %10.6f' % sess.run(W),
          'B = %10.6f' % sess.run(b))
# Out:
# 0 Loss = 1291.91431 W =   1.613977 B =   0.405374
# 1 Loss = 753.34668  W =   3.434580 B =   0.900428
# 2 Loss = 439.49277  W =   4.824946 B =   1.276345
# 3 Loss = 256.59113  W =   5.886878 B =   1.561321
# 4 Loss = 150.00183  W =   6.698085 B =   1.776882
# 5 Loss = 87.88369   W =   7.317894 B =   1.939459
# 6 Loss = 51.68114   W =   7.791589 B =   2.061596
# 7 Loss = 30.58093   W =   8.153744 B =   2.152869
# 8 Loss = 18.28164   W =   8.430748 B =   2.220587
# 9 Loss = 11.11111   W =   8.642748 B =   2.270331
# 10 Loss = 6.92940    W =   8.805123 B =   2.306359
# 11 Loss = 4.48944    W =   8.929615 B =   2.331925
# 12 Loss = 3.06449    W =   9.025185 B =   2.349509
# 13 Loss = 2.23108    W =   9.098674 B =   2.361008
# 14 Loss = 1.74241    W =   9.155305 B =   2.367867
# 15 Loss = 1.45465    W =   9.199066 B =   2.371192
# 16 Loss = 1.28399    W =   9.233000 B =   2.371824
# 17 Loss = 1.18160    W =   9.259431 B =   2.370407
# 18 Loss = 1.11900    W =   9.280131 B =   2.367433
# 19 Loss = 1.07961    W =   9.296456 B =   2.363277
# 20 Loss = 1.05378    W =   9.309440 B =   2.358224
# 21 Loss = 1.03585    W =   9.319870 B =   2.352493
# 22 Loss = 1.02256    W =   9.328349 B =   2.346251
# 23 Loss = 1.01199    W =   9.335338 B =   2.339625
# 24 Loss = 1.00302    W =   9.341186 B =   2.332712
# 25 Loss = 0.99500    W =   9.346162 B =   2.325587
# 26 Loss = 0.98756    W =   9.350471 B =   2.318305
# 27 Loss = 0.98047    W =   9.354269 B =   2.310911
# 28 Loss = 0.97360    W =   9.357676 B =   2.303437
# 29 Loss = 0.96689    W =   9.360781 B =   2.295907
# 30 Loss = 0.96028    W =   9.363654 B =   2.288342
# 31 Loss = 0.95374    W =   9.366350 B =   2.280756
# 32 Loss = 0.94728    W =   9.368908 B =   2.273160
# 33 Loss = 0.94087    W =   9.371359 B =   2.265562
# 34 Loss = 0.93450    W =   9.373726 B =   2.257970
# 35 Loss = 0.92819    W =   9.376028 B =   2.250387
# 36 Loss = 0.92192    W =   9.378279 B =   2.242817
# 37 Loss = 0.91570    W =   9.380488 B =   2.235264
# 38 Loss = 0.90951    W =   9.382665 B =   2.227730
# 39 Loss = 0.90337    W =   9.384814 B =   2.220215
# 40 Loss = 0.89728    W =   9.386942 B =   2.212722
# 41 Loss = 0.89122    W =   9.389051 B =   2.205251
# 42 Loss = 0.88520    W =   9.391145 B =   2.197803
# 43 Loss = 0.87923    W =   9.393225 B =   2.190378
# 44 Loss = 0.87329    W =   9.395292 B =   2.182977
# 45 Loss = 0.86740    W =   9.397349 B =   2.175600
# 46 Loss = 0.86154    W =   9.399397 B =   2.168247
# 47 Loss = 0.85572    W =   9.401435 B =   2.160918
# 48 Loss = 0.84995    W =   9.403464 B =   2.153614
# 49 Loss = 0.84421    W =   9.405485 B =   2.146334
# 50 Loss = 0.83851    W =   9.407498 B =   2.139078
# 51 Loss = 0.83285    W =   9.409504 B =   2.131846
# 52 Loss = 0.82723    W =   9.411502 B =   2.124639
# 53 Loss = 0.82165    W =   9.413493 B =   2.117456
# 54 Loss = 0.81610    W =   9.415478 B =   2.110298
# 55 Loss = 0.81059    W =   9.417455 B =   2.103163
# 56 Loss = 0.80512    W =   9.419425 B =   2.096052
# 57 Loss = 0.79968    W =   9.421389 B =   2.088966
# 58 Loss = 0.79429    W =   9.423346 B =   2.081903
# 59 Loss = 0.78892    W =   9.425296 B =   2.074864
# 60 Loss = 0.78360    W =   9.427238 B =   2.067849
# 61 Loss = 0.77831    W =   9.429175 B =   2.060858
# 62 Loss = 0.77305    W =   9.431106 B =   2.053890
# 63 Loss = 0.76783    W =   9.433029 B =   2.046946
# 64 Loss = 0.76265    W =   9.434946 B =   2.040025
# 65 Loss = 0.75750    W =   9.436856 B =   2.033128
# 66 Loss = 0.75239    W =   9.438760 B =   2.026254
# 67 Loss = 0.74731    W =   9.440658 B =   2.019404
# 68 Loss = 0.74226    W =   9.442549 B =   2.012576
# 69 Loss = 0.73725    W =   9.444433 B =   2.005772
# 70 Loss = 0.73228    W =   9.446312 B =   1.998990
# 71 Loss = 0.72734    W =   9.448184 B =   1.992232
# 72 Loss = 0.72242    W =   9.450049 B =   1.985496
# 73 Loss = 0.71755    W =   9.451909 B =   1.978783
# 74 Loss = 0.71270    W =   9.453762 B =   1.972093
# 75 Loss = 0.70789    W =   9.455609 B =   1.965425
# 76 Loss = 0.70312    W =   9.457450 B =   1.958780
# 77 Loss = 0.69837    W =   9.459284 B =   1.952158
# 78 Loss = 0.69366    W =   9.461112 B =   1.945557
# 79 Loss = 0.68897    W =   9.462934 B =   1.938980
# 80 Loss = 0.68432    W =   9.464749 B =   1.932424
# 81 Loss = 0.67970    W =   9.466559 B =   1.925891
# 82 Loss = 0.67511    W =   9.468363 B =   1.919379
# 83 Loss = 0.67056    W =   9.470160 B =   1.912890
# 84 Loss = 0.66603    W =   9.471951 B =   1.906422
# 85 Loss = 0.66153    W =   9.473737 B =   1.899977
# 86 Loss = 0.65707    W =   9.475516 B =   1.893553
# 87 Loss = 0.65263    W =   9.477289 B =   1.887151
# 88 Loss = 0.64823    W =   9.479056 B =   1.880771
# 89 Loss = 0.64385    W =   9.480818 B =   1.874412
# 90 Loss = 0.63950    W =   9.482574 B =   1.868075
# 91 Loss = 0.63519    W =   9.484323 B =   1.861759
# 92 Loss = 0.63090    W =   9.486066 B =   1.855464
# 93 Loss = 0.62664    W =   9.487803 B =   1.849191
# 94 Loss = 0.62241    W =   9.489535 B =   1.842939
# 95 Loss = 0.61821    W =   9.491261 B =   1.836708
# 96 Loss = 0.61404    W =   9.492982 B =   1.830498
# 97 Loss = 0.60989    W =   9.494696 B =   1.824309
# 98 Loss = 0.60577    W =   9.496404 B =   1.818141
# 99 Loss = 0.60168    W =   9.498106 B =   1.811994

# %%
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())

  for step in range(1001):
    _, loss_val = sess.run([train_op, loss], feed_dict={X:x_data, Y:y_data})
    if step % 10 == 0:
      print(step, loss_val, sess.run(W), sess.run(b))
  
  print('Y = {Weight} * X + {Bias}'.format(Weight = sess.run(W), Bias = sess.run(b)))
  print('X:5, Y:', sess.run(score, feed_dict={X:5}))
  print('X:2.5, Y:', sess.run(score, feed_dict={X:2.5}))
# Out:
# 0 1017.41833 [2.385971] [0.9885575]
# 10 6.005883 [8.771541] [2.654111]
# 20 1.3452036 [9.224563] [2.6798785]
# 30 1.2378312 [9.278081] [2.5983107]
# 40 1.1566793 [9.303983] [2.5123034]
# 50 1.0809253 [9.327285] [2.4286785]
# 60 1.0101354 [9.349694] [2.3478065]
# 70 0.943981 [9.37135] [2.269625]
# 80 0.8821596 [9.392284] [2.1940465]
# 90 0.82438344 [9.412521] [2.120985]
# 100 0.7703942 [9.432085] [2.0503561]
# 110 0.71994066 [9.450995] [1.9820799]
# 120 0.6727921 [9.469277] [1.9160771]
# 130 0.6287298 [9.48695] [1.852272]
# 140 0.58755493 [9.504034] [1.7905917]
# 150 0.54907376 [9.52055] [1.7309654]
# 160 0.5131157 [9.536516] [1.6733246]
# 170 0.47951174 [9.55195] [1.6176031]
# 180 0.44810805 [9.56687] [1.5637373]
# 190 0.41876158 [9.581293] [1.5116651]
# 200 0.39133492 [9.595237] [1.4613268]
# 210 0.36570653 [9.608715] [1.4126644]
# 220 0.34175673 [9.621745] [1.3656226]
# 230 0.31937382 [9.63434] [1.3201474]
# 240 0.29845756 [9.646517] [1.2761866]
# 250 0.2789115 [9.658288] [1.23369]
# 260 0.2606459 [9.669665] [1.1926088]
# 270 0.24357593 [9.680667] [1.1528955]
# 280 0.22762337 [9.6913] [1.1145042]
# 290 0.21271646 [9.70158] [1.0773915]
# 300 0.1987855 [9.711517] [1.0415145]
# 310 0.18576762 [9.721124] [1.006832]
# 320 0.1736006 [9.730411] [0.9733045]
# 330 0.1622322 [9.7393875] [0.9408936]
# 340 0.15160705 [9.748065] [0.9095622]
# 350 0.14167854 [9.756454] [0.8792745]
# 360 0.13239968 [9.7645645] [0.8499949]
# 370 0.12372895 [9.772406] [0.82169014]
# 380 0.11562564 [9.779984] [0.7943278]
# 390 0.10805309 [9.787311] [0.76787674]
# 400 0.10097718 [9.794393] [0.7423066]
# 410 0.09436373 [9.80124] [0.71758777]
# 420 0.08818395 [9.807858] [0.69369215]
# 430 0.08240855 [9.814257] [0.6705923]
# 440 0.077011935 [9.820442] [0.64826167]
# 450 0.07196815 [9.826421] [0.62667453]
# 460 0.06725518 [9.8322] [0.605807]
# 470 0.06285029 [9.837789] [0.58563405]
# 480 0.058734216 [9.843191] [0.56613266]
# 490 0.054887466 [9.8484125] [0.54728013]
# 500 0.051293235 [9.85346] [0.52905566]
# 510 0.047933783 [9.85834] [0.51143813]
# 520 0.04479409 [9.863057] [0.49440715]
# 530 0.04186073 [9.867617] [0.4779436]
# 540 0.03911948 [9.8720255] [0.4620282]
# 550 0.036557302 [9.876287] [0.44664267]
# 560 0.03416323 [9.880406] [0.4317695]
# 570 0.031926014 [9.884389] [0.41739175]
# 580 0.029835016 [9.888239] [0.40349293]
# 590 0.027881175 [9.89196] [0.39005658]
# 600 0.026055446 [9.895558] [0.37706798]
# 610 0.024348859 [9.899035] [0.36451188]
# 620 0.0227543 [9.902397] [0.3523741]
# 630 0.02126419 [9.905648] [0.34064034]
# 640 0.019871471 [9.90879] [0.3292974]
# 650 0.018570099 [9.911827] [0.31833184]
# 660 0.01735383 [9.9147625] [0.30773157]
# 670 0.016217709 [9.917601] [0.2974849]
# 680 0.015155529 [9.920344] [0.28757936]
# 690 0.014162915 [9.922998] [0.27800298]
# 700 0.013235454 [9.925563] [0.2687453]
# 710 0.0123686325 [9.928041] [0.25979573]
# 720 0.01155852 [9.930437] [0.25114426]
# 730 0.010801409 [9.932754] [0.24278104]
# 740 0.010094106 [9.934993] [0.23469648]
# 750 0.009433176 [9.937158] [0.22688122]
# 760 0.008815227 [9.939251] [0.2193259]
# 770 0.008237938 [9.941274] [0.21202229]
# 780 0.0076984526 [9.943229] [0.20496204]
# 790 0.007194209 [9.945119] [0.19813679]
# 800 0.0067231 [9.946947] [0.19153881]
# 810 0.0062828697 [9.948713] [0.18516053]
# 820 0.0058712605 [9.950421] [0.17899467]
# 830 0.0054866634 [9.952072] [0.17303406]
# 840 0.0051275054 [9.953669] [0.16727212]
# 850 0.004791655 [9.955211] [0.16170195]
# 860 0.0044777407 [9.956703] [0.15631737]
# 870 0.004184696 [9.958144] [0.15111205]
# 880 0.0039105816 [9.959538] [0.14608029]
# 890 0.0036544665 [9.960886] [0.14121579]
# 900 0.0034151792 [9.962189] [0.13651302]
# 910 0.0031914166 [9.963447] [0.13196714]
# 920 0.002982417 [9.964664] [0.12757279]
# 930 0.0027870708 [9.96584] [0.12332472]
# 940 0.0026046522 [9.966979] [0.1192182]
# 950 0.0024339617 [9.968079] [0.11524804]
# 960 0.0022745463 [9.969141] [0.11141019]
# 970 0.0021256655 [9.970168] [0.10770041]
# 980 0.0019864335 [9.971162] [0.10411438]
# 990 0.0018563453 [9.972122] [0.10064746]
# 1000 0.001734738 [9.973051] [0.09729595]
# Y = [9.973051] * X + [0.09729595]
# X:5, Y: [49.962555]
# X:2.5, Y: [25.029924]
