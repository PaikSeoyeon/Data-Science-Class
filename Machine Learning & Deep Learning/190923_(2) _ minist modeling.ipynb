# %% [markdown]
# # 1. 데이터 셋 생성

# %% [markdown]
# ## 훈련 셋 시험 셋 불러오기

# %%
(x_train, y_train), (x_test, y_test) = mnist.laod_data()
x_train = x_train.reshape(60000, width*height).astype('float32') / 255.0
x_test = x_test.reshape(60000, width*height).astype('float32') / 255.0

# %% [markdown]
# ## 훈련 셋 검증 셋 분리

# %%
x_val = x_train[50000:]
y_val = y_train[50000:]
x_train = x_train[:50000]
y_train = y_train[:50000]

# %% [markdown]
# ## one-hot 인코딩

# %%
y_train = np_utils.to_categorical(y_train)
y_val = np_utils.to_categorical(y_val)
y_test = np_utils.to_categorical(y_test)

# %% [markdown]
# # 2. 모델 구성

# %%
model = Sequential()
model.add(Dense(256, input_dim = width*height, activation='relu'))
model.add(Dense(256, activation = 'relu'))
model.add(Dense(256, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))

# %%
model = Sequential()
model.add(Dense(256, input_dim = h*w, activation='relu'))
model.add(Dense(256, activation = 'relu'))

# %% [markdown]
# # 3. 모델 학습과정 설정

# %%
model.compile(loss='categorical_crossentropy', optimizer = 'sgd', metrics=['accuracy'])

# %%
model.compile(loss='categoriccal_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %% [markdown]
# # 4. 모델 학습

# %%
hist = model.fit(x_train, y_train, epochs=30, batch_size=32, validation_data=(x_val, y_val))

# %%
hist = model.fit(xtrain, y_train, e)

# %% [markdown]
# # 5. 학습 과정 살펴보기

# %% [markdown]
# # 6. 모델 평가

# %%
loss_and_metrics = model.evaluate(x_test, y_test, batch_size=32)
print('evaluation loss and metrics')
print(loss_and_metrics)

# %% [markdown]
# # 7. 모델 사용

# %%
yhat_test = model.predict(x_test, batch_size=32)
