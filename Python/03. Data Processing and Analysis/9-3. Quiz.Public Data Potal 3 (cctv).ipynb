# %%
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %matplotlib inline
plt.rcParams["figure.figsize"] = [12,6]

# %%
df = pd.read_csv('data/public_seoul_cctv_2017.csv', encoding='EUC-KR')
df
# Out:
#     경찰서      개소      대수
# 0    중부     304     517
# 1    종로     214     480
# 2   남대문     159     202
# 3   서대문     376   1,131
# 4    혜화     215     481
# 5    용산     632   1,897
# 6    성북     453   1,276
# 7   동대문     486   1,396
# 8    마포     703     952
# 9   영등포     745   1,122
# 10   성동     497   1,252
# 11   동작     484   1,184
# 12   광진     637     642
# 13   서부     216     748
# 14   강북     696     840
# 15   금천     382   1,163
# 16   중랑     727     887
# 17   강남     596   1,612
# 18   관악   1,042   1,804
# 19   강서     576     870
# 20   강동     679     872
# 21   종암     295     767
# 22   구로     695   1,691
# 23   서초     344   1,079
# 24   양천     763   2,234
# 25   송파     675     779
# 26   노원   1,288   1,416
# 27   방배     236     830
# 28   은평     339   1,058
# 29   도봉     472     485
# 30   수서     677   1,856
# 31   총계  16,603  33,523

# %%
for i in range(len(df['개소'])):
    df['개소'][i] = df['개소'][i].replace(',', '')

df['개소'][i]
# Out:
# pandas.core.series.Series

# %%
pd.to_numeric(df['개소'])
# Out:
# 0       304
# 1       214
# 2       159
# 3       376
# 4       215
# 5       632
# 6       453
# 7       486
# 8       703
# 9       745
# 10      497
# 11      484
# 12      637
# 13      216
# 14      696
# 15      382
# 16      727
# 17      596
# 18     1042
# 19      576
# 20      679
# 21      295
# 22      695
# 23      344
# 24      763
# 25      675
# 26     1288
# 27      236
# 28      339
# 29      472
# 30      677
# 31    16603
# Name: 개소, dtype: int64

# %%
for i in range(len(df['대수'])):
    df['대수'][i] = df['대수'][i].replace(',', '')

df['대수']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-6478a73bf2d1> in <module>
#       1 for i in range(len(df['대수'])):
# ----> 2     df['대수'][i] = df['대수'][i].replace(',', '')
#       3
#       4 df['대수']
#
# AttributeError: 'numpy.int64' object has no attribute 'replace'

# %% [markdown]
# #### 과제1 : 서울시 구별 경찰서수와 CCTV설치수 조사

# %%
plt.figure(figsize=(20,10))

sns.set_color_codes

A = df_police.values[:]
B = df_cctv.values[:]

X = df_police.index[:]

plt.bar(X, A, color='b')
plt.bar(X, B, color='r', bottom=A)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-164-08f704d886e1> in <module>
#       5
#       6 plt.bar(X, A, color='b')
# ----> 7 plt.bar(X, B, color='r', bottom=A)
#       8 plt.show()
#
# C:\Python\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2432     return gca().bar(
#    2433         x, height, width=width, bottom=bottom, align=align,
# -> 2434         **({"data": data} if data is not None else {}), **kwargs)
#    2435
#    2436
#
# C:\Python\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
df_police.values[
]
# Out:
# array([ 304,  214,  159,  376,  215,  632,  453,  486,  703,  745,  497,
#         484,  637,  216,  696,  382,  727,  596, 1042,  576,  679,  295,
#         695,  344,  763,  675, 1288,  236,  339,  472,  677], dtype=int64)

# %% [markdown]
# #### 과제2 : 경찰서관할별 CCTV (설치대수) 조사

# %%
df_police = pd.Series(df['개소'].values, index=df['경찰서'].values)
df_police
# Out:
# 중부       304
# 종로       214
# 남대문      159
# 서대문      376
# 혜화       215
# 용산       632
# 성북       453
# 동대문      486
# 마포       703
# 영등포      745
# 성동       497
# 동작       484
# 광진       637
# 서부       216
# 강북       696
# 금천       382
# 중랑       727
# 강남       596
# 관악      1042
# 강서       576
# 강동       679
# 종암       295
# 구로       695
# 서초       344
# 양천       763
# 송파       675
# 노원      1288
# 방배       236
# 은평       339
# 도봉       472
# 수서       677
# 총계     16603
# dtype: int64

# %%
df_police=df_police.drop(df_police.index[-1])

# %%
df['대수'] = pd.to_numeric(df['대수'])

df_cctv = pd.Series(df['대수'].values, index=df['경찰서'].values)
df_cctv
# Out:
# 중부       517
# 종로       480
# 남대문      202
# 서대문     1131
# 혜화       481
# 용산      1897
# 성북      1276
# 동대문     1396
# 마포       952
# 영등포     1122
# 성동      1252
# 동작      1184
# 광진       642
# 서부       748
# 강북       840
# 금천      1163
# 중랑       887
# 강남      1612
# 관악      1804
# 강서       870
# 강동       872
# 종암       767
# 구로      1691
# 서초      1079
# 양천      2234
# 송파       779
# 노원      1416
# 방배       830
# 은평      1058
# 도봉       485
# 수서      1856
# 총계     33523
# dtype: int64

# %%
df_cctv=df_cctv.drop(df_cctv.index[-1])

# %% [markdown]
# #### 과제3 : 과제1,2를 하나의 그래프로 나타내보자.

# %%
plt.rcParams["figure.figsize"] = [15,15]
df_police.plot(kind='pie', title = '경찰서관할 파출소(개소수)');

# %%
plt.rcParams["figure.figsize"] = [15,15]
df_cctv.plot(kind='pie', title = '경찰서관할 파출소(개소수)');

# %% [markdown]
# #### 과제4 : 경찰서수가 가장 많은구, CCTV가 가장 많이 설치된구를 파이차트로 나타내보자

# %% [markdown]
# #### 과제5 : 모든 그래프를 1Page Report로 나타내보자

# %%
tmp = "1,042,058"

# %%
tmp.replace(",", "")
# Out:
# '1042058'
